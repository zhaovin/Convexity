# %%
set_printoptions(threshold=10000)
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','libpath_windows')))
from idpresearch import *

# %%
inputcsvdir = os.path.abspath('../data/CA/')
outputcsvdir = os.path.abspath('../data/')
df= pd.read_csv(inputcsvdir + '\\CA.csv')
df = df[['Date Time', 'Event', 'Tenor']]
df['Date Time']= pd.to_datetime(df['Date Time'])
df = df.set_index(['Date Time'])
df['Event'] = df['Event'].map(lambda x: x.lower())

# %%
def parse_to_get_size(s, ccy):
    if ("bln" in s) or ("billion" in s):
        s = s.replace('billion', 'bln')
        y = float(s.split("bln")[0].split(ccy)[1].replace(' ', ''))
    elif ("mln" in s) or ("million" in s):
        s = s.replace('million', 'mln')
        y = float(s.split("mln")[0].split(ccy)[1].replace(' ', '')) / 1000
    elif ("tln" in s) or ("tillion" in s):
        s = s.replace('tillion', 'tln')
        y = float(s.split("tln")[0].split(ccy)[1].replace(' ', '')) * 1000
    else:
        y = np.nan
    return y
def parse_to_get_yield(s):
    if ("yld" in s):
        if("=" in s):
            y = float(s.split("yld=")[1].split("%")[0].replace(' ', '')) / 100
        else:
            y = float(s.split("yld")[1].split("%")[0].replace(' ', '')) / 100
    elif ("yield" in s):
        y = float(s.split("yield ")[1].split("%")[0].replace(' ', '')) / 100
    else:
        y = np.nan
    return y
def parse_to_get_tenor(s):
    if ("-year" in s) :
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("year" in s):
        s = s.replace(' year', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("-yr" in s):
        s = s.replace('-yr', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])        
    else:
        y = np.nan
    return y
def parse_to_get_iib(s):
    if ("tips" in s) or ("link" in s) or ('frn' in s) or ('floating' in s) or ('i/l' in s) or ('rrb' in s) or ('real return' in s):
        y = 1
    else:
        y = 0
    return y
def parse_to_get_maturity(s):
    if('notes' in s):
        s = s.replace('notes', 'bonds')
        y = int(s.split(" bonds")[0].split(' ')[-1])
    elif ("bonds" in s):
        y = int(s.split(" bonds")[0].split(' ')[-1])
    else:
        y = np.nan
    return y

# %%
df['IIB'] = df['Event'].map(parse_to_get_iib)
df['Yield'] = df['Event'].map(parse_to_get_yield)
df['Size'] = df['Event'].apply(parse_to_get_size, args=("cad",))
df['Bid/Cover'] = np.nan
df['Tail']= np.nan
df = df[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]
df.tail(n = 20)
# Out:
#                                                                  Event  IIB  \
# Date Time
# 2012-08-15 12:00:00  canada sells cad3.4 bln 5-year notes; avg yld ...    0
# 2012-08-29 12:00:00  canada sells cad2.9 bln 3-year notes; avg yld ...    0
# 2012-09-12 12:00:00  canada sells cad400 mln 30-year rrb's; avg yld...    1
# 2012-09-19 12:00:00  canada sells cad1.4 bln 30-year notes; avg yld...    0
# 2012-09-26 12:00:00  canada sells cad3.3 bln 2-year notes; avg yld ...    0
# 2012-10-10 12:00:00  canada sells cad2.7 bln 3 year notes; avg yld ...    0
# 2012-10-17 12:00:00  canada sells cad2.9 bln 10 year notes; avg yld...    0
# 2012-11-07 12:00:00  canada sells cad3.5 bln 5 year notes; avg yld ...    0
# 2012-11-14 12:00:00  canada sells cad3.3 bln 2 year notes; avg yld ...    0
# 2012-11-28 12:00:00  canada sells cad1.6 bln 30 year bonds; avg yld...    0
# 2012-12-05 12:00:00  canada to sell cad700 mln 30 year real return ...    1
# 2012-12-12 12:00:00  canada sells cad2.7 bln 3 year notes; avg yld ...    0
# 2012-12-19 12:00:00  canada sells cad3.3 bln 2 year notes; avg yld ...    0
# 2013-01-09 12:00:00  canada sells cad3.4 bln 5 year notes; avg yld ...    0
# 2013-01-16 12:00:00  canada sells cad3.3 bln 2 year notes; avg yld ...    0
# 2013-01-30 12:00:00  canada sells cad2.9 bln 10 year notes; avg yld...    0
# 2013-02-06 12:00:00  canada sells cad2.7 bln 3 year notes; avg yld ...    0
# 2013-02-13 12:00:00  canada sells cad3.3 bln 2 year notes; avg yld ...    0
# 2013-02-20 12:00:00  canada sells cad400 mln 30 year rrb's; avg yld...    1
# 2013-02-27 12:00:00               canada sells cad3.4 bln 5 year notes    0
#
#                      Tenor    Yield  Size  Bid/Cover  Tail
# Date Time
# 2012-08-15 12:00:00      5  0.01538   3.4        NaN   NaN
# 2012-08-29 12:00:00      3  0.01278   2.9        NaN   NaN
# 2012-09-12 12:00:00     30  0.00549   0.4        NaN   NaN
# 2012-09-19 12:00:00     30  0.02466   1.4        NaN   NaN
# 2012-09-26 12:00:00      2  0.01106   3.3        NaN   NaN
# 2012-10-10 12:00:00      3  0.01282   2.7        NaN   NaN
# 2012-10-17 12:00:00     10  0.01987   2.9        NaN   NaN
# 2012-11-07 12:00:00      5  0.01367   3.5        NaN   NaN
# 2012-11-14 12:00:00      2  0.01106   3.3        NaN   NaN
# 2012-11-28 12:00:00     30  0.02289   1.6        NaN   NaN
# 2012-12-05 12:00:00     30      NaN   0.7        NaN   NaN
# 2012-12-12 12:00:00      3  0.01205   2.7        NaN   NaN
# 2012-12-19 12:00:00      2  0.01152   3.3        NaN   NaN
# 2013-01-09 12:00:00      5  0.01494   3.4        NaN   NaN
# 2013-01-16 12:00:00      2  0.01201   3.3        NaN   NaN
# 2013-01-30 12:00:00     10  0.02112   2.9        NaN   NaN
# 2013-02-06 12:00:00      3  0.01317   2.7        NaN   NaN
# 2013-02-13 12:00:00      2  0.01168   3.3        NaN   NaN
# 2013-02-20 12:00:00     30  0.00619   0.4        NaN   NaN
# 2013-02-27 12:00:00      5      NaN   3.4        NaN   NaN
#
# [20 rows x 7 columns]

# %% [markdown]
# ## Updates with latest calendar

# %%
#update
df_new= pd.read_csv(inputcsvdir + '\\CA_2013-2014.csv')
df_new = df_new[['Date Time', 'Event']]
df_new = df_new.dropna(how = 'any')
df_new['Date Time']= pd.to_datetime(df_new['Date Time'])
df_new = df_new.set_index(['Date Time'])
df_new['Event'] = df_new['Event'].map(lambda x: x.lower())

# %%
idx = [("sell" in x) and ("bond" in x) for x in df_new['Event']]
df_new = df_new.ix[idx, :]
df_new['Tenor'] = df_new['Event'].map(parse_to_get_tenor)
df_new['IIB'] = df_new['Event'].map(parse_to_get_iib)
df_new['Yield'] = df_new['Event'].map(parse_to_get_yield)
df_new['Size'] = df_new['Event'].apply(parse_to_get_size, args=("cad",))
df_new['Bid/Cover'] = np.nan
df_new['Tail']= np.nan
df_new['Year Today'] = [x.year for x in df_new.index]
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
df_all = pd.concat([df, df_new], axis = 0) 
df_all.to_csv(inputcsvdir + '\\CA_updated.csv')
