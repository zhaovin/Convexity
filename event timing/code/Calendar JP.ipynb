# %%
set_printoptions(threshold=10000)
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','path')))

from idpresearch import *

# %%
inputcsvdir = os.path.abspath('../data/JP/')
outputcsvdir = os.path.abspath('../data/')
df= pd.read_csv(inputcsvdir + '\\JP.csv')
df = df[['Date Time', 'Event']]
df['Date Time']= pd.to_datetime(df['Date Time'])
df = df.set_index(['Date Time'])
df['Event'] = df['Event'].map(lambda x: x.lower())

# %%
def parse_to_get_size(s, ccy):
    if('jy' in s):
       s = s.replace('jy', 'jpy')
    if ("bln" in s) or ("billion" in s):
        s = s.replace('billion', 'bln')
        y = float(s.split("bln")[0].split(ccy)[1].replace(' ', ''))
    elif ("mln" in s) or ("million" in s):
        s = s.replace('million', 'mln')
        y = float(s.split("mln")[0].split(ccy)[1].replace(' ', '')) / 1000
    elif ("tln" in s) or ("tillion" in s):
        s = s.replace('tillion', 'tln')
        y = float(s.split("tln")[0].split(ccy)[1].replace(' ', '')) * 1000
    else:
        y = np.nan
    return y
def parse_to_get_yield(s):
    if ("yld" in s):
        if("=" in s):
            y = float(s.split("yld=")[1].split("%")[0].replace(' ', '')) / 100
        else:
            y = float(s.split("yld")[1].split("%")[0].replace(' ', '')) / 100
    elif ("yield" in s):
        y = float(s.split("yield ")[1].split("%")[0].replace(' ', '')) / 100
    else:
        y = np.nan
    return y
def parse_to_get_tenor(s):
    if ("-year" in s) :
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("year" in s):
        s = s.replace(' year', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("-yr" in s):
        s = s.replace('-yr', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])        
    else:
        y = np.nan
    return y
def parse_to_get_iib(s):
    if ("tips" in s) or ("link" in s) or ('frn' in s) or ('floating' in s):
        y = 1
    else:
        y = 0
    return y

# %%
df['Tenor'] = df['Event'].map(parse_to_get_tenor)
df['IIB'] = df['Event'].map(parse_to_get_iib)
df['Yield'] = df['Event'].map(parse_to_get_yield)
df['Size'] = df['Event'].apply(parse_to_get_size, args=("jpy",))
df['Bid/Cover'] = np.nan
df['Tail']= np.nan
df = df[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]
df.tail(n = 10)
# Out:
#                                                                  Event  IIB  \
# Date Time
# 2013-01-08 12:45:00  japan sells jpy2.299 tln 0.8% 10-yr bonds; avg...    0
# 2013-01-10 12:45:00  japan sells jpy699.1 bln 30-year bonds; avg yl...    0
# 2013-01-16 12:45:00  japan sells jpy2.499 tln 5-year bonds; avg yld...    0
# 2013-01-24 12:45:00  japan sells jpy1.199 tln 20-year bonds; avg yl...    0
# 2013-01-31 12:45:00  japan sells jpy2.699 tln 2-yr bonds; avg yld 0...    0
# 2013-02-05 12:45:00  japan sells jpy2.399tln 0.8% 10-yr bonds; avg ...    0
# 2013-02-13 12:45:00  japan sells jpy399.2bln 2% 40-year bonds; avg ...    0
# 2013-02-19 12:45:00  japan sells jpy2.699 tln 5-year bonds; avg yld...    0
# 2013-02-21 12:45:00                        japan to sell 20-year bonds    0
# 2013-02-28 12:45:00  japan sells jpy2.699 tln 2-yr bonds; avg yld 0...    0
#
#                      Tenor    Yield    Size  Bid/Cover  Tail
# Date Time
# 2013-01-08 12:45:00     10  0.00822  2299.0        NaN   NaN
# 2013-01-10 12:45:00     30  0.01990   699.1        NaN   NaN
# 2013-01-16 12:45:00      5  0.00156  2499.0        NaN   NaN
# 2013-01-24 12:45:00     20  0.01750  1199.0        NaN   NaN
# 2013-01-31 12:45:00      2  0.00070  2699.0        NaN   NaN
# 2013-02-05 12:45:00     10  0.00795  2399.0        NaN   NaN
# 2013-02-13 12:45:00     40  0.02120   399.2        NaN   NaN
# 2013-02-19 12:45:00      5  0.00122  2699.0        NaN   NaN
# 2013-02-21 12:45:00     20      NaN     NaN        NaN   NaN
# 2013-02-28 12:45:00      2  0.00047  2699.0        NaN   NaN
#
# [10 rows x 7 columns]

# %%
#update
df_new= pd.read_csv(inputcsvdir + '\\JP_2013-2014.csv')
df_new = df_new[['Date Time', 'Event']]
df_new = df_new.dropna(how = 'any')
df_new['Date Time']= pd.to_datetime(df_new['Date Time'])
df_new = df_new.set_index(['Date Time'])
df_new['Event'] = df_new['Event'].map(lambda x: x.lower())

# %%
idx = [("sell" in x) and (("notes"in x) or ("bonds" in x) or ("frn" in x)) for x in df_new['Event']]
df_new = df_new.ix[idx, :]

# %%
df_new['Tenor'] = df_new['Event'].map(parse_to_get_tenor)
df_new['IIB'] = df_new['Event'].map(parse_to_get_iib)
df_new['Yield'] = df_new['Event'].map(parse_to_get_yield)
df_new['Size'] = df_new['Event'].apply(parse_to_get_size, args=("jpy",))
df_new['Bid/Cover'] = np.nan
df_new['Tail']= np.nan
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
df_all = pd.concat([df, df_new], axis = 0)
df_all.to_csv(inputcsvdir + '\\JP_updated.csv')
