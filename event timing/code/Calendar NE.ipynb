# %%
set_printoptions(threshold=10000)
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','libpath_windows')))
from idpresearch import *

# %%
def parse_to_get_size(s, ccy):
    if ("bln" in s) or ("billion" in s):
        s = s.replace('billion', 'bln')
        y = float(s.split("bln")[0].split(ccy)[1].replace(' ', ''))
    elif ("mln" in s) or ("million" in s):
        s = s.replace('million', 'mln')
        y = float(s.split("mln")[0].split(ccy)[1].replace(' ', '')) / 1000
    elif ("tln" in s) or ("tillion" in s):
        s = s.replace('tillion', 'tln')
        y = float(s.split("tln")[0].split(ccy)[1].replace(' ', '')) * 1000
    else:
        y = np.nan
    return y
def parse_to_get_yield(s):
    if ("yld" in s):
        if("=" in s):
            y = float(s.split("yld=")[1].split("%")[0].replace(' ', '')) / 100
        else:
            y = float(s.split("yld")[1].split("%")[0].replace(' ', '')) / 100
    elif ("yield" in s):
        y = float(s.split("yield ")[1].split("%")[0].replace(' ', '')) / 100
    else:
        y = np.nan
    return y
def parse_to_get_tenor(s, year):
    #specified by year
    if ("-year" in s) :
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("year" in s):
        s = s.replace(' year', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("-yr" in s):
        s = s.replace('-yr', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    #specified by due belgium sells eur950 mln 5% bonds due 2035;
    elif ("due" in s):
        mat = int(s.split("due ")[1].replace(';',' ').split(' ')[0])
        y = mat - year
    elif ('bonds' in s):
        mat = int(s.split(" bonds")[0].split(' ')[-1])
        y = mat - year
    else:
        y = np.nan
    return y
def parse_to_get_iib(s):
    if ("tips" in s) or ("link" in s) or ('frn' in s) or ('floating' in s) or ('i/l' in s) or ('rrb' in s) or ('real return' in s):
        y = 1
    else:
        y = 0
    return y
def parse_to_get_maturity(s):
    if('notes' in s):
        s = s.replace('notes', 'bonds')
        y = int(s.split(" bonds")[0].split(' ')[-1])
    elif ("bonds" in s):
        y = int(s.split(" bonds")[0].split(' ')[-1])
    else:
        y = np.nan
    return y

# %%
#update
inputcsvdir = os.path.abspath('../data/NE/')
df_new= pd.read_csv(inputcsvdir + '\\NE_2005-2014.csv')
df_new = df_new[['Date Time', 'Event']]
df_new = df_new.dropna(how = 'any')
df_new['Date Time']= pd.to_datetime(df_new['Date Time'])
df_new = df_new.set_index(['Date Time'])
df_new['Event'] = df_new['Event'].map(lambda x: x.lower())

# %%
idx = [("sell" in x) and ("bond" in x) for x in df_new['Event']]
df_new = df_new.ix[idx, :]
# convert all to eu and then convert all back to eur
df_new['Event'] = df_new['Event'].map(lambda x: x.replace('eur', 'eu'))
df_new['Event'] = df_new['Event'].map(lambda x: x.replace('eu', 'eur'))
# get tenor
df_new['Tenor'] = np.nan
for i in range(len(df_new)):
    df_new['Tenor'].ix[i] = parse_to_get_tenor(df_new['Event'].ix[i], df_new.index[i].year)

df_new['IIB'] = df_new['Event'].map(parse_to_get_iib)
df_new['Yield'] = df_new['Event'].map(parse_to_get_yield)
df_new['Size'] = df_new['Event'].apply(parse_to_get_size, args=("eur",))
df_new['Bid/Cover'] = np.nan
df_new['Tail'] = np.nan
#df_new['Year Today'] = [x.year for x in df_new.index]
#df_new['Tenor'] = df_new['Maturity'] - df_new['Year Today']
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
df_new.to_csv(inputcsvdir + '\\NE_updated.csv')

# %%
df_new.tail(n = 30)
# Out:
#                                                                  Event  IIB  \
# Date Time
# 2012-09-25 10:00:00  netherlands sells eur1.92 bln 2.5% 2033 bonds;...    0
# 2012-10-09 10:00:00  netherlands sells eur2.255 bln 1.25% 2018 bond...    0
# 2012-11-13 10:00:00  netherlands sells eur2.12 bln 2.25% 2022 bonds...    0
# 2012-11-27 10:00:00  netherlands sells eur2.4 bln 0.75% 2015 bonds;...    0
# 2013-01-08 10:00:00  netherlands sells eur3.2 bln 0% 2016 bonds; yl...    0
# 2013-01-22 10:00:00  netherlands sells eur575 mln 1% 2014 bonds; yl...    0
# 2013-01-22 10:00:00  netherlands sells eur1.51 bln 3.75% 2042 bonds...    0
# 2013-02-12 10:00:00  netherlands sells eur2.685 bln 1.25% 2018 bond...    0
# 2013-03-12 10:00:00  netherlands sells eur3.48 bln 0% 2016 bonds; y...    0
# 2013-03-19 13:22:00  netherlands sells eur6.52 bln 1.75% 2023 bonds...    0
# 2013-03-26 10:00:00  netherlands sells eur2.225 bln 1.25% 2018 bond...    0
# 2013-04-09 10:00:00  netherlands sells eur2.035 bln 2.5% 2033 bonds...    0
# 2013-05-14 10:00:00  netherlands sells eur1.5 bln 1.25% 2018 bonds;...    0
# 2013-05-28 10:00:00  netherlands sells eur2.32 bln 1.75% 2023 bonds...    0
# 2013-06-11 10:30:00  netherlands sells eur2.65 bln 0% 2016 bonds; y...    0
# 2013-06-25 10:00:00      netherlands sells eur6.1 bln 1.25% 2019 bonds    0
# 2013-07-09 10:00:00  netherlands sells eur2.12 bln 1.75% 2023 bonds...    0
# 2013-07-23 10:00:00  netherlands sells eur1 bln 3.25% 2021 bonds; y...    0
# 2013-07-23 10:00:00  netherlands sells eur785 mln 3.75% 2042 bonds;...    0
# 2013-09-10 10:00:00  netherlands sells eur2 bln 1.75% 2023 bonds; y...    0
# 2013-09-24 10:30:00  netherlands sells eur2.35 bln 0% 2016 bonds; y...    0
# 2013-10-08 10:00:00  netherlands sells eur1.775 bln 1.25% 2019 bond...    0
# 2013-11-12 10:30:00  netherlands sells eur1.955 bln 1.75% 2023 bond...    0
# 2013-11-26 10:30:00  netherlands sells eur2.4 bln 0% 2016 bonds; yl...    0
# 2014-01-14 10:30:00  netherlands sells eur3.5 bln 0.5% 2017 bonds; ...    0
# 2014-01-28 10:30:00  netherlands sells eur890 mln 4% 2016 bonds; yl...    0
# 2014-01-28 10:30:00  netherlands sells eur450 mln 4% 2037 bonds; yl...    0
# 2014-02-11 10:30:00  netherlands sells eur2.3 bln 1.25% 2019 bonds;...    0
# 2014-02-18 10:30:00      netherlands sells eur3.7 bln 2.75% 2047 bonds    0
# 2014-03-11 10:30:00  netherlands sells eur2.83 bln 0.5% 2017 bonds;...    0
#
#                      Tenor    Yield   Size  Bid/Cover  Tail
# Date Time
# 2012-09-25 10:00:00     21  0.02497  1.920        NaN   NaN
# 2012-10-09 10:00:00      6  0.00861  2.255        NaN   NaN
# 2012-11-13 10:00:00     10  0.01579  2.120        NaN   NaN
# 2012-11-27 10:00:00      3  0.00129  2.400        NaN   NaN
# 2013-01-08 10:00:00      3  0.00318  3.200        NaN   NaN
# 2013-01-22 10:00:00      1  0.00054  0.575        NaN   NaN
# 2013-01-22 10:00:00     29  0.02408  1.510        NaN   NaN
# 2013-02-12 10:00:00      5  0.00884  2.685        NaN   NaN
# 2013-03-12 10:00:00      3  0.00395  3.480        NaN   NaN
# 2013-03-19 13:22:00     10  0.01831  6.520        NaN   NaN
# 2013-03-26 10:00:00      5  0.00727  2.225        NaN   NaN
# 2013-04-09 10:00:00     20  0.02265  2.035        NaN   NaN
# 2013-05-14 10:00:00      5  0.00611  1.500        NaN   NaN
# 2013-05-28 10:00:00     10  0.01783  2.320        NaN   NaN
# 2013-06-11 10:30:00      3  0.00495  2.650        NaN   NaN
# 2013-06-25 10:00:00      6      NaN  6.100        NaN   NaN
# 2013-07-09 10:00:00     10  0.02061  2.120        NaN   NaN
# 2013-07-23 10:00:00      8  0.01538  1.000        NaN   NaN
# 2013-07-23 10:00:00     29  0.02581  0.785        NaN   NaN
# 2013-09-10 10:00:00     10  0.02412  2.000        NaN   NaN
# 2013-09-24 10:30:00      3  0.00435  2.350        NaN   NaN
# 2013-10-08 10:00:00      6  0.01215  1.775        NaN   NaN
# 2013-11-12 10:30:00     10  0.02104  1.955        NaN   NaN
# 2013-11-26 10:30:00      3  0.00275  2.400        NaN   NaN
# 2014-01-14 10:30:00      3  0.00572  3.500        NaN   NaN
# 2014-01-28 10:30:00      2  0.00325  0.890        NaN   NaN
# 2014-01-28 10:30:00     23  0.02674  0.450        NaN   NaN
# 2014-02-11 10:30:00      5  0.00907  2.300        NaN   NaN
# 2014-02-18 10:30:00     33      NaN  3.700        NaN   NaN
# 2014-03-11 10:30:00      3  0.00421  2.830        NaN   NaN
#
# [30 rows x 7 columns]
