# %%
#setup
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date
import datetime

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','libpath_windows')))

from idpresearch import *

params = utillib.PathUtil(projectname = 'AS auction', 
                          inputcsvdir = os.path.abspath('../data/AS'), 
                          outputdir = os.path.abspath('../output/AS'),
                          resourcedir = os.path.abspath(config.get('IDPResearch','libpath_windows') + '/resources'))
inputcsvdir = os.path.abspath('../data/AS')

risk = risklib.Risk()
sig = siglib.Sig()
plt = plotlib.Plot(params)
io = iolib.IO(params)

# %%
import ET_utils as et
# %load_ext autoreload
# %autoreload

# %%
# plot mean function
def plot_data_mean(data_dict, contracts, index_dates, column_times, plot_date_st, plot_date_ed, day_st, day_end, time_int_n):
    rcParams['figure.figsize'] = 18, 3
    ax1 = grid()
    hold(True)
    for i_contract in contracts:
        #convert to dataframe
        df_data = pd.DataFrame(data = data_dict[i_contract], index = index_dates, columns = column_times)
        df_data.ix[plot_date_st:plot_date_ed].mean(axis = 0).T.plot(ax = ax1, label = i_contract)
    for i in range(1,day_end - day_st):
        axvline(x = i* time_int_n-1, color = 'k')
    legend(loc = 'best') 
    return ax1

# %%
def plot_pos_data(data_pos, index_dates, column_times, plot_date_st, plot_date_ed, day_st, day_end, time_int_n):
    rcParams['figure.figsize'] = 18, 3
    #convert to dataframe
    df_data = pd.DataFrame(data = data_pos, index = index_dates, columns = column_times)
    ax1 = df_data.ix[plot_date_st:plot_date_ed].T.plot(grid = True)
    for i in range(1,day_end - day_st):
        axvline(x= i* time_int_n-1, color = 'k')
    legend(loc = 'best')
    return ax1

# %%
def Event_pl_pos_output(Assets, data, col_name, filename):
    # save data to filename csv file
    df_data = pd.DataFrame()
    col_list= [x + y for x in Assets for y in col_name]
    for i in range(len(Assets)):
        df_data = pd.concat([df_data, data[i]], axis = 1)
    df_data.columns = col_list
    df_data.to_csv(filename)

# %%
AS = pd.read_csv(inputcsvdir +'//'+ 'AS_updated.csv', index_col= 0, parse_dates= True, infer_datetime_format= True)
AS = AS['2005-05-30':'2014-01-30']  #         
AS['Date'] = [x.date() for x in AS.index]
AS['Week Day'] = [x.weekday() for x in AS.index]

# %%
AS['Tenor'].value_counts().sort_index()
# Out:
# 2      1
# 4      5
# 5     15
# 6      9
# 7      7
# 8      2
# 9     11
# 10    24
# 11    11
# 12     2
# 14     1
# 15     4
# 16     3
# 17     2
# 21     2
# 26     4
# 27     2
# 28     2
# 29     1
# 30     3
# 31     2
# 32     1
# 49     1
# 50     1
# dtype: int64

# %%
AS['Week Day'].value_counts().sort_index()
# Out:
# 1    115
# 2      1
# dtype: int64

# %% [markdown]
# ## Austria

# %%
Events_dates = set(AS['Date'].ix[(AS['Tenor'] >= 2).values & (AS['Tenor'] <= 50).values])
#Events_dates = [x for x in Events_dates if x > datetime.date(2012,  5, 1 )]
Events_dates = [x for x in Events_dates if x > datetime.date(2007,  3, 1 )]
Events_dates = sort(Events_dates)
Week_days = [i_date.weekday() for i_date in Events_dates]
Event_date_index = pd.DatetimeIndex(Events_dates)
df_week_days = pd.DataFrame(Week_days, index = Event_date_index, columns= ['Week of the day'])
len_events = len(Events_dates)
len_events
# Out:
# 64

# %%
Events_dates
# Out:
# array([datetime.date(2007, 3, 6), datetime.date(2007, 4, 3),
#        datetime.date(2007, 5, 2), datetime.date(2007, 6, 5),
#        datetime.date(2007, 7, 3), datetime.date(2007, 10, 9),
#        datetime.date(2007, 12, 4), datetime.date(2008, 2, 5),
#        datetime.date(2008, 3, 4), datetime.date(2008, 4, 1),
#        datetime.date(2008, 5, 6), datetime.date(2008, 6, 3),
#        datetime.date(2008, 7, 8), datetime.date(2008, 9, 2),
#        datetime.date(2008, 12, 9), datetime.date(2009, 2, 10),
#        datetime.date(2009, 3, 10), datetime.date(2009, 4, 7),
#        datetime.date(2009, 5, 5), datetime.date(2009, 6, 9),
#        datetime.date(2009, 7, 7), datetime.date(2009, 8, 4),
#        datetime.date(2009, 9, 1), datetime.date(2009, 10, 6),
#        datetime.date(2009, 11, 3), datetime.date(2010, 2, 9),
#        datetime.date(2010, 3, 9), datetime.date(2010, 4, 6),
#        datetime.date(2010, 5, 4), datetime.date(2010, 6, 8),
#        datetime.date(2010, 7, 6), datetime.date(2010, 8, 3),
#        datetime.date(2010, 9, 7), datetime.date(2010, 10, 5),
#        datetime.date(2010, 11, 9), datetime.date(2011, 2, 1),
#        datetime.date(2011, 3, 1), datetime.date(2011, 4, 5),
#        datetime.date(2011, 5, 3), datetime.date(2011, 6, 7),
#        datetime.date(2011, 7, 5), datetime.date(2011, 9, 6),
#        datetime.date(2011, 10, 4), datetime.date(2011, 11, 8),
#        datetime.date(2012, 1, 10), datetime.date(2012, 3, 6),
#        datetime.date(2012, 4, 10), datetime.date(2012, 5, 8),
#        datetime.date(2012, 6, 12), datetime.date(2012, 9, 4),
#        datetime.date(2012, 10, 2), datetime.date(2012, 11, 6),
#        datetime.date(2012, 12, 11), datetime.date(2013, 1, 8),
#        datetime.date(2013, 2, 5), datetime.date(2013, 3, 5),
#        datetime.date(2013, 5, 7), datetime.date(2013, 6, 4),
#        datetime.date(2013, 7, 2), datetime.date(2013, 8, 6),
#        datetime.date(2013, 9, 3), datetime.date(2013, 11, 5),
#        datetime.date(2013, 12, 10), datetime.date(2014, 1, 7)], dtype=object)

# %%
#load main event data
#contracts = ['OE', 'RX', 'UB', 'OAT', 'IK']
contracts = ['OE', 'RX', 'UB']
t_index = pd.date_range('2013-01-01 08:06', '2013-01-01 18:11', freq = '5min')
time_zone = 'Europe/Berlin'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = -3
day_end = 3
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]
event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates, len_events)
event_data_vol_adj_dict['UB_OE'] = event_data_vol_adj_dict['UB'] - event_data_vol_adj_dict['OE']
event_data_vol_adj_dict['UB_RX'] = event_data_vol_adj_dict['UB'] - event_data_vol_adj_dict['RX']
event_data_vol_adj_dict['RX_OE'] = event_data_vol_adj_dict['RX'] - event_data_vol_adj_dict['OE']
#event_data_vol_adj_dict['RX_OAT'] = event_data_vol_adj_dict['RX'] - event_data_vol_adj_dict['OAT']
#event_data_vol_adj_dict['RX_IK'] = event_data_vol_adj_dict['RX'] - event_data_vol_adj_dict['IK']

# %%
ax1 = plot_data_mean(event_data_vol_adj_dict, ['OE','RX', 'UB'], Event_date_index, time_interval_str, '2012', '2012', day_st, day_end, time_int_n)

# %%
ax1 = plot_data_mean(event_data_vol_adj_dict, ['UB_RX', 'UB_OE',], Event_date_index, time_interval_str, '2007', '2011', day_st, day_end, time_int_n)

# %%
ax1 = plot_data_mean(event_data_vol_adj_dict, ['UB_RX', 'UB_OE'], Event_date_index, time_interval_str, '2013', '2014', day_st, day_end, time_int_n)
