# %%
set_printoptions(threshold=10000)
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','libpath_windows')))
from idpresearch import *

# %%
def parse_to_get_size(s, ccy):
    if ("bln" in s) or ("billion" in s):
        s = s.replace('billion', 'bln')
        y = float(s.split("bln")[0].split(ccy)[1].replace(' ', ''))
    elif ("mln" in s) or ("million" in s):
        s = s.replace('million', 'mln')
        y = float(s.split("mln")[0].split(ccy)[1].replace(' ', '')) / 1000
    elif ("tln" in s) or ("tillion" in s):
        s = s.replace('tillion', 'tln')
        y = float(s.split("tln")[0].split(ccy)[1].replace(' ', '')) * 1000
    else:
        y = np.nan
    return y
def parse_to_get_yield(s):
    if ("yld" in s):
        if("=" in s):
            y = float(s.split("yld=")[1].split("%")[0].replace(' ', '')) / 100
        else:
            y = float(s.split("yld")[1].split("%")[0].replace(' ', '')) / 100
    elif ("yield" in s):
        y = float(s.split("yield ")[1].split("%")[0].replace(' ', '')) / 100
    else:
        y = np.nan
    return y
def parse_to_get_tenor(s, year):
    #specified by year
    if ("-year" in s) :
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("year" in s):
        s = s.replace(' year', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("-yr" in s):
        s = s.replace('-yr', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    #specified by due belgium sells eur950 mln 5% bonds due 2035;
    elif ("due" in s):
        mat = int(s.split("due ")[1].replace(';',' ').split(' ')[0])
        y = mat - year
    elif ('bonds' in s):
        mat = int(s.split(" bonds")[0].split(' ')[-1])
        y = mat - year
    else:
        y = np.nan
    return y
def parse_to_get_iib(s):
    if ("tips" in s) or ("link" in s) or ('frn' in s) or ('floating' in s) or ('i/l' in s) or ('rrb' in s) or ('real return' in s):
        y = 1
    else:
        y = 0
    return y
def parse_to_get_maturity(s):
    if('notes' in s):
        s = s.replace('notes', 'bonds')
        y = int(s.split(" bonds")[0].split(' ')[-1])
    elif ("bonds" in s):
        y = int(s.split(" bonds")[0].split(' ')[-1])
    else:
        y = np.nan
    return y

# %%
#update
inputcsvdir = os.path.abspath('../data/AS/')
df_new= pd.read_csv(inputcsvdir + '\\AS_2005-2014.csv')
df_new = df_new[['Date Time', 'Event']]
df_new = df_new.dropna(how = 'any')
df_new['Date Time']= pd.to_datetime(df_new['Date Time'])
df_new = df_new.set_index(['Date Time'])
df_new['Event'] = df_new['Event'].map(lambda x: x.lower())

# %%
idx = [("sell" in x) and ("bond" in x) for x in df_new['Event']]
df_new = df_new.ix[idx, :]
# convert all to eu and then convert all back to eur
df_new['Event'] = df_new['Event'].map(lambda x: x.replace('eur', 'eu'))
df_new['Event'] = df_new['Event'].map(lambda x: x.replace('eu', 'eur'))
# get tenor
df_new['Tenor'] = np.nan
for i in range(len(df_new)):
    df_new['Tenor'].ix[i] = parse_to_get_tenor(df_new['Event'].ix[i], df_new.index[i].year)

df_new['IIB'] = df_new['Event'].map(parse_to_get_iib)
df_new['Yield'] = df_new['Event'].map(parse_to_get_yield)
df_new['Size'] = df_new['Event'].apply(parse_to_get_size, args=("eur",))
df_new['Bid/Cover'] = np.nan
df_new['Tail'] = np.nan
#df_new['Year Today'] = [x.year for x in df_new.index]
#df_new['Tenor'] = df_new['Maturity'] - df_new['Year Today']
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
df_new.to_csv(inputcsvdir + '\\AS_updated.csv')

# %%
df_new.tail(n = 30)
# Out:
#                                                                  Event  IIB  \
# Date Time
# 2012-10-02 11:00:00  austria sells eur550 mln 1.95% 2019 bonds; yld...    0
# 2012-11-06 11:00:00  austria sells eur660 mln 1.95% 2019 bonds; yld...    0
# 2012-11-06 11:00:00  austria sells eur660 mln 3.4% 2022 bonds; yld ...    0
# 2012-12-11 11:00:00  austria sells eur550 mln 1.95% 2019 bonds; yld...    0
# 2012-12-11 11:00:00  austria sells eur550 mln 3.4% 2022 bonds; yld ...    0
# 2013-01-08 11:00:00  austria sells eur550 mln 3.8% 2062 bonds; yld ...    0
# 2013-01-08 11:00:00  austria sells eur550 mln 3.4% 2022 bonds; yld ...    0
# 2013-02-05 11:00:00  austria sells eur550 mln 3.4% 2022 bonds; yld ...    0
# 2013-02-05 11:00:00  austria sells eur550 mln 1.95% 2019 bonds; yld...    0
# 2013-03-05 11:00:00  austria sells eur770 mln 3.15% 2044 bonds; yld...    0
# 2013-03-05 11:00:00  austria sells eur880 mln 3.4% 2022 bonds; yld ...    0
# 2013-05-07 11:00:00  austria sells eur660 mln 1.95% 2019 bonds; yld...    0
# 2013-05-07 11:00:00  austria sells eur660 mln 1.75% 2023 bonds; yld...    0
# 2013-06-04 11:00:00  austria sells eur715 mln 1.75% 2023 bonds; yld...    0
# 2013-06-04 11:00:00  austria sells eur715 mln 4.3% 2017 bonds; yld ...    0
# 2013-07-02 11:15:00  austria sells eur660 mln 2.4% 2034 bonds; yld ...    0
# 2013-07-02 11:15:00  austria sells eur990 mln 4.65% 2018 bonds; yld...    0
# 2013-08-06 11:30:00  austria sells eur770 mln 1.75% 2023 bonds; yld...    0
# 2013-09-03 11:15:00  austria sells eur800 mln 1.75% 2023 bonds; yld...    0
# 2013-09-03 11:15:00  austria sells eur700 mln 3.15% 2044 bonds; yld...    0
# 2013-11-05 11:15:00  austria sells eur990 mln 1.15% 2018 bonds; yld...    0
# 2013-11-05 11:15:00  austria sells eur660 mln 3.65% 2022 bonds; yld...    0
# 2013-12-10 11:15:00  austria sells eur800 mln 2.4% 2034 bonds; yld ...    0
# 2013-12-10 11:15:00  austria sells eur700 mln 3.4% 2022 bonds; yld ...    0
# 2014-01-07 11:15:00  austria sells eur600 mln 1.75% 2023 bonds; yld...    0
# 2014-01-07 11:15:00  austria sells eur500 mln 3.15% 2044 bonds; yld...    0
# 2014-02-04 11:30:00  austria sells eur400 mln 3.8% 2062 bonds; yld ...    0
# 2014-02-04 11:30:00  austria sells eur700 mln 1.15% 2018 bonds; yld...    0
# 2014-03-04 11:30:00  austria sells eur500 mln 1.75% 2023 bonds; yld...    0
# 2014-03-04 11:30:00  austria sells eur600 mln 1.15% 2018 bonds; yld...    0
#
#                      Tenor    Yield   Size  Bid/Cover  Tail
# Date Time
# 2012-10-02 11:00:00      7  0.01326  0.550        NaN   NaN
# 2012-11-06 11:00:00      7  0.01218  0.660        NaN   NaN
# 2012-11-06 11:00:00     10  0.01888  0.660        NaN   NaN
# 2012-12-11 11:00:00      7  0.01021  0.550        NaN   NaN
# 2012-12-11 11:00:00     10  0.01706  0.550        NaN   NaN
# 2013-01-08 11:00:00     49  0.02820  0.550        NaN   NaN
# 2013-01-08 11:00:00      9  0.01838  0.550        NaN   NaN
# 2013-02-05 11:00:00      9  0.01934  0.550        NaN   NaN
# 2013-02-05 11:00:00      6  0.01294  0.550        NaN   NaN
# 2013-03-05 11:00:00     31  0.02648  0.770        NaN   NaN
# 2013-03-05 11:00:00      9  0.01726  0.880        NaN   NaN
# 2013-05-07 11:00:00      6  0.00794  0.660        NaN   NaN
# 2013-05-07 11:00:00     10  0.01621  0.660        NaN   NaN
# 2013-06-04 11:00:00     10  0.01903  0.715        NaN   NaN
# 2013-06-04 11:00:00      4  0.00642  0.715        NaN   NaN
# 2013-07-02 11:15:00     21  0.02685  0.660        NaN   NaN
# 2013-07-02 11:15:00      5  0.00893  0.990        NaN   NaN
# 2013-08-06 11:30:00     10  0.02072  0.770        NaN   NaN
# 2013-09-03 11:15:00     10  0.02317  0.800        NaN   NaN
# 2013-09-03 11:15:00     31  0.03009  0.700        NaN   NaN
# 2013-11-05 11:15:00      5  0.00932  0.990        NaN   NaN
# 2013-11-05 11:15:00      9  0.01769  0.660        NaN   NaN
# 2013-12-10 11:15:00     21  0.02779  0.800        NaN   NaN
# 2013-12-10 11:15:00      9  0.01984  0.700        NaN   NaN
# 2014-01-07 11:15:00      9  0.02174  0.600        NaN   NaN
# 2014-01-07 11:15:00     30  0.02982  0.500        NaN   NaN
# 2014-02-04 11:30:00     48  0.02789  0.400        NaN   NaN
# 2014-02-04 11:30:00      4  0.00749  0.700        NaN   NaN
# 2014-03-04 11:30:00      9  0.01851  0.500        NaN   NaN
# 2014-03-04 11:30:00      4  0.00736  0.600        NaN   NaN
#
# [30 rows x 7 columns]
