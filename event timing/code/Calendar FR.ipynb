# %%
set_printoptions(threshold=10000)
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','path')))

from idpresearch import *

# %%
inputcsvdir = os.path.abspath('../data/FR/')
outputcsvdir = os.path.abspath('../data/')
df= pd.read_csv(inputcsvdir + '\\FR_template.csv', index_col= 0, parse_dates= True, infer_datetime_format= True)
df['Event'] = df['Event'].map(lambda x: x.lower())

# %%
df.tail()
# Out:
#                                                                  Event  IIB  \
# Date Time
# 2013-07-04 10:50:00  france sells eur5.36 bln 1.75% 2023 bonds; yld...    0
# 2013-07-04 10:50:00  france sells eur2.63 bln 2.75% 2027 bonds; yld...    0
# 2013-07-18 10:50:00  france sells eur2.094 bln 0.25% 2015 bonds; yl...    0
# 2013-07-18 10:50:00  france sells eur1.774 bln 3.75% 2017 bonds; yl...    0
# 2013-07-18 10:50:00  france sells eur4.12 bln 1% 2018 bonds; yld 1.09%    0
#
#                      Tenor   Yield   Size  Bid/Cover  Tail
# Date Time
# 2013-07-04 10:50:00     10  0.0232  5.360        NaN   NaN
# 2013-07-04 10:50:00     14  0.0284  2.630        NaN   NaN
# 2013-07-18 10:50:00      2  0.0031  2.094        NaN   NaN
# 2013-07-18 10:50:00      4  0.0066  1.774        NaN   NaN
# 2013-07-18 10:50:00      5  0.0109  4.120        NaN   NaN
#
# [5 rows x 7 columns]

# %%
def parse_to_get_size(s, ccy):  
    if ("bln" in s) or ("billion" in s):
        s = s.replace('billion', 'bln')
        y = float(s.split(" bln")[0].split(ccy)[1].replace(' ', ''))
    elif ("mln" in s) or ("millian" in s) :
        s = s.replace('millian', 'mln')
        y = float(s.split(" mln")[0].split(ccy)[1].replace(' ', '')) / 1000
    else:
        y = np.nan
    return y
def parse_to_get_yield(s):
    if ("yld" in s):
        y = float(s.split("yld ")[1].split("%")[0].replace(' ', '')) / 100
    elif ("yield" in s):
        y = float(s.split("yield ")[1].split("%")[0].replace(' ', '')) / 100
    else:
        y = np.nan
    return y
def parse_to_get_maturity(s):
    if('notes' in s):
        s = s.replace('notes', 'bonds')
        y = int(s.split(" bonds")[0].split(' ')[-1])
    elif ("bonds" in s):
        y = int(s.split(" bonds")[0].split(' ')[-1])
    else:
        y = np.nan
    return y
def parse_to_get_iib(s):
    if ("i/l" in s) or ("inflation" in s) or ("link" in s)  :
        y = 1
    else:
        y = 0
    return y

# %%
#update
df_new= pd.read_csv(inputcsvdir + '\\FR_2013-2014.csv')
df_new = df_new[['Date Time', 'Event']]
df_new = df_new.dropna(how = 'any')
df_new['Date Time']= pd.to_datetime(df_new['Date Time'])
df_new = df_new.set_index(['Date Time'])
df_new['Event'] = df_new['Event'].map(lambda x: x.lower())

# %%
idx = [("sell" in x) and ("bond" in x) for x in df_new['Event']]
df_new = df_new.ix[idx, :]
df_new['Maturity'] = df_new['Event'].map(parse_to_get_maturity)
df_new['IIB'] = df_new['Event'].map(parse_to_get_iib)
df_new['Yield'] = df_new['Event'].map(parse_to_get_yield)
df_new['Size'] = df_new['Event'].apply(parse_to_get_size, args=("eur",))
df_new['Bid/Cover'] = np.nan
df_new['Tail']= np.nan
df_new['Year Today'] = [x.year for x in df_new.index]
df_new['Tenor'] = df_new['Maturity'] - df_new['Year Today']
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]
df_new
# Out:
#                                                                  Event  IIB  \
# Date Time
# 2013-09-05 10:50:00  france sells eur2.485 bln 3.25% 2021 bonds; yl...    0
# 2013-09-05 10:50:00  france sells eur4.24 bln 1.75% 2023 bonds; yld...    0
# 2013-09-05 10:50:00  france sells eur1.66 bln 3.25% 2045 bonds; yld...    0
# 2013-09-19 10:50:00  france sells eur2.525 bln 0.25% 2015 bonds; yl...    0
# 2013-09-19 10:50:00  france sells eur3.05 bln 1% 2018 bonds; yld 1.23%    0
#
#                      Tenor   Yield   Size  Bid/Cover  Tail
# Date Time
# 2013-09-05 10:50:00      8  0.0217  2.485        NaN   NaN
# 2013-09-05 10:50:00     10  0.0257  4.240        NaN   NaN
# 2013-09-05 10:50:00     32  0.0360  1.660        NaN   NaN
# 2013-09-19 10:50:00      2  0.0039  2.525        NaN   NaN
# 2013-09-19 10:50:00      5  0.0123  3.050        NaN   NaN
# 2013-09-19 11:50:00      8  0.0024  0.455        NaN   NaN
# 2013-09-19 11:50:00     11  0.0080  0.535        NaN   NaN
# 2013-09-19 11:50:00     14  0.0095  0.494        NaN   NaN
# 2013-10-03 10:50:00     10  0.0237  5.105        NaN   NaN
# 2013-10-03 10:50:00     16  0.0302  2.355        NaN   NaN
# 2013-10-17 10:50:00      5  0.0124  4.080        NaN   NaN
# 2013-10-17 11:50:00     10  0.0060  0.625        NaN   NaN
# 2013-10-17 11:50:00     14  0.0097  0.430        NaN   NaN
# 2013-10-17 11:50:00     27  0.0126  0.430        NaN   NaN
# 2013-11-07 10:50:00     11  0.0241  4.283        NaN   NaN
# 2013-11-07 10:50:00     32  0.0341  2.210        NaN   NaN
# 2013-11-21 10:50:00      3  0.0031  3.425        NaN   NaN
# 2013-11-21 10:50:00      5  0.0102  3.025        NaN   NaN
# 2013-11-21 11:50:00      5 -0.0026  0.749        NaN   NaN
# 2013-11-21 11:50:00     11  0.0079  0.315        NaN   NaN
# 2013-12-05 10:50:00      5  0.0083  1.320        NaN   NaN
# 2013-12-05 10:50:00      8  0.0177  1.335        NaN   NaN
# 2013-12-05 10:50:00     14  0.0281  1.335        NaN   NaN
# 2014-01-09 10:50:00      6  0.0167  1.475        NaN   NaN
# 2014-01-09 10:50:00     10  0.0251  5.046        NaN   NaN
# 2014-01-09 10:50:00     46  0.0353  1.805        NaN   NaN
# 2014-01-23 10:50:00      2  0.0034  2.225        NaN   NaN
# 2014-01-23 10:50:00      4  0.0094  1.885        NaN   NaN
# 2014-01-23 10:50:00      5  0.0124  3.820        NaN   NaN
# 2014-01-23 11:50:00      4 -0.0020  0.605        NaN   NaN
# 2014-01-23 11:50:00     10  0.0076  0.335        NaN   NaN
# 2014-02-06 10:50:00     10  0.0225  4.055        NaN   NaN
# 2014-02-06 10:50:00     13  0.0266  2.891        NaN   NaN
# 2014-02-06 10:50:00     18  0.0288  1.040        NaN   NaN
#
# [34 rows x 7 columns]

# %%
df_all = pd.concat([df, df_new], axis = 0)

# %%
df_all.to_csv(inputcsvdir + '\\FR_updated.csv')
