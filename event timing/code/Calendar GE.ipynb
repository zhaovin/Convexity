# %%
set_printoptions(threshold=10000)
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','path')))

from idpresearch import *

# %%
inputcsvdir = os.path.abspath('../data/GE/')
outputcsvdir = os.path.abspath('../data/')
df= pd.read_csv(inputcsvdir + '\\GE_template.csv', index_col= 0, parse_dates= True, infer_datetime_format= True)
df['Event'] = df['Event'].map(lambda x: x.lower())
df = df[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
def parse_to_get_size(s, ccy):
    if('jy' in s):
       s = s.replace('jy', 'jpy')
    if ("bln" in s) or ("billion" in s):
        s = s.replace('billion', 'bln')
        y = float(s.split("bln")[0].split(ccy)[1].replace(' ', ''))
    elif ("mln" in s) or ("million" in s):
        s = s.replace('million', 'mln')
        y = float(s.split("mln")[0].split(ccy)[1].replace(' ', '')) / 1000
    elif ("tln" in s) or ("tillion" in s):
        s = s.replace('tillion', 'tln')
        y = float(s.split("tln")[0].split(ccy)[1].replace(' ', '')) * 1000
    else:
        y = np.nan
    return y
def parse_to_get_yield(s):
    if ("yld" in s):
        if("=" in s):
            y = float(s.split("yld=")[1].split("%")[0].replace(' ', '')) / 100
        else:
            y = float(s.split("yld")[1].split("%")[0].replace(' ', '')) / 100
    elif ("yield" in s):
        y = float(s.split("yield ")[1].split("%")[0].replace(' ', '')) / 100
    else:
        y = np.nan
    return y
def parse_to_get_tenor(s):
    if ("-year" in s) :
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("year" in s):
        s = s.replace(' year', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])
    elif ("-yr" in s):
        s = s.replace('-yr', '-year')
        y = int(s.split("-year")[0].split(" ")[-1])        
    else:
        y = np.nan
    return y
def parse_to_get_iib(s):
    if ("tips" in s) or ("link" in s) or ('frn' in s) or ('floating' in s) or ('i/l' in s):
        y = 1
    else:
        y = 0
    return y
def parse_to_get_maturity(s):
    if('notes' in s):
        s = s.replace('notes', 'bonds')
        y = int(s.split(" bonds")[0].split(' ')[-1])
    elif ("bonds" in s):
        y = int(s.split(" bonds")[0].split(' ')[-1])
    else:
        y = np.nan
    return y

# %%
#update
df_new= pd.read_csv(inputcsvdir + '\\GE_2013-2014.csv')
df_new = df_new[['Date Time', 'Event']]
df_new = df_new.dropna(how = 'any')
df_new['Date Time']= pd.to_datetime(df_new['Date Time'])
df_new = df_new.set_index(['Date Time'])
df_new['Event'] = df_new['Event'].map(lambda x: x.lower())

# %%
idx = [("sell" in x) and (("notes"in x) or ("bonds" in x) or ("frn" in x)) for x in df_new['Event']]
df_new = df_new.ix[idx, :]

# %%
df_new['IIB'] = df_new['Event'].map(parse_to_get_iib)
df_new['Maturity'] = df_new['Event'].map(parse_to_get_maturity)
df_new['Year Today'] = [x.year for x in df_new.index]
df_new['Tenor'] = df_new['Maturity'] - df_new['Year Today']
df_new['Yield'] = df_new['Event'].map(parse_to_get_yield)
df_new['Size'] = df_new['Event'].apply(parse_to_get_size, args=("eur",))
df_new['Bid/Cover'] = np.nan
df_new['Tail']= np.nan
df_new = df_new[['Event', 'IIB', 'Tenor', 'Yield', 'Size', 'Bid/Cover', 'Tail']]

# %%
df_all = pd.concat([df, df_new], axis = 0)
df_all.to_csv(inputcsvdir + '\\GE_updated.csv')

# %%
# Out:
#                                                                  Event  IIB  \
# 2005-09-14 11:07:00  germany sells eu6.979 bln 2-year notes; yield ...    0
# 2005-09-20 11:00:00  germany to sell up to eu7 billion of 5-year bo...    0
# 2005-09-21 11:07:00  germany sells eu5.858 bln 5-year notes; yield ...    0
# 2005-10-12 11:07:00  germany sells eu 7 bln 2-year notes; yld 2.44%...    0
# 2005-10-26 11:00:00  germany sells eu4.151 bln 5-year notes; yield ...    0
# 2005-11-23 11:00:00  germany sells eu6.483 bln 10-year bonds; yield...    0
# 2005-11-30 11:00:00  germany sells eu4.172 bln 5-year notes; yield ...    0
# 2005-12-14 11:00:00  germany sells eu6.010 bln 2-year notes; yield ...    0
# 2006-01-04 11:30:00  germany sells eu 6.212 bln 10-year bonds; yiel...    0
# 2006-01-18 11:30:00  germany sells eu6.522 bln 2-year notes; yield ...    0
# 2006-01-25 11:30:00  germany sells eu 5.391 bln 30-year bonds; yiel...    0
# 2006-02-15 11:30:00  germany sells eu6.016 bln 10-year bonds; yield...    0
# 2006-03-08 11:30:00  germany sells eu 9 bln notes due 2008; yld 3.1...    0
# 2006-03-22 11:30:00  germany sells eu 6.450 bln 5-year notes; yield...    0
# 2006-04-19 11:30:00  germany sells eu5.980 bln 2-year notes; yield ...    0
# 2006-04-26 11:00:00  germany sells eu 4.744 bln 5-year notes; avg y...    0
# 2006-05-17 11:07:00  germany sells eu 8 bln bonds due 2016; yield 4...    0
# 2006-06-21 11:00:00  germany sells eu7 billion 3.25% bonds due 2008...    0
# 2006-07-05 11:00:00  germany sells eu 8 bln 4% bonds due 2016; yld ...    0
# 2006-07-19 11:00:00  germany sells eu 7 bln 3.25% notes due 2008; y...    0
# 2006-07-26 11:00:00  germany to sell additional 4% bonds due 2037 (...    0
# 2006-08-16 11:00:00  germany sells eu 7 bln 4% bonds due 2016; yiel...    0
# 2006-09-27 11:00:00  germany sells eu8 bln 5-year notes; yield 3.59...    0
# 2006-10-11 11:00:00  germany sells eu6 bln add'l 3.5% notes due 200...    0
# 2006-10-25 11:00:00  germany sells additional eu 5 bln 5-year notes...    0
# 2006-11-15 11:00:00  germany sells eu 7 bln 10-year bonds; yield 3.72%    0
# 2006-11-29 11:00:00  germany sells additional eu 4 bln 5-year notes...    0
# 2006-12-13 11:00:00   germany sells eu 7 bln 2-year notes; yield 3.71%    0
# 2007-01-03 11:30:00  germany sells additional eu 7 bln 10-year bond...    0
# 2007-01-17 11:30:00  germany sells add'l eu 7 billion 2-year notes;...    0
# 2007-01-24 11:30:00  germany sells eu4.943 bln 30-year bonds; yield...    0
# 2007-02-14 11:30:00  germany to sells add'l eu6 bln 10-year bonds; ...    0
# 2007-03-14 11:30:00  germany sells eu8 billion 2-year notes; yield ...    0
# 2007-03-28 11:30:00  germany sells eu 6 bln 4% 5-year notes; yield ...    0
# 2006-04-19 11:30:00      2  0.0326  5.980        NaN   NaN
# 2006-04-26 11:00:00      5  0.0376  4.744        NaN   NaN
# 2006-05-17 11:07:00     10  0.0401  8.000        NaN   NaN
# 2006-06-21 11:00:00      2  0.0347  7.000        NaN   NaN
# 2006-07-05 11:00:00     10  0.0410  8.000        NaN   NaN
# 2006-07-19 11:00:00      2  0.0357  7.000        NaN   NaN
# 2006-07-26 11:00:00     30     NaN    NaN        NaN   NaN
# 2006-08-16 11:00:00     10  0.0397  7.000        NaN   NaN
# 2006-09-27 11:00:00      5  0.0359  8.000        NaN   NaN
# 2006-10-11 11:00:00      2  0.0365  6.000        NaN   NaN
# 2006-10-25 11:00:00      5  0.0381  5.000        NaN   NaN
# 2006-11-15 11:00:00     10  0.0372  7.000        NaN   NaN
# 2006-11-29 11:00:00      5  0.0363  4.000        NaN   NaN
# 2006-12-13 11:00:00      2  0.0371  7.000        NaN   NaN
# 2007-01-03 11:30:00     10  0.0394  7.000        NaN   NaN
# 2007-01-17 11:30:00      2  0.0390  7.000        NaN   NaN
# 2007-01-24 11:30:00     30  0.0411  4.943        NaN   NaN
# 2007-02-14 11:30:00     10  0.0411  6.000        NaN   NaN
# 2007-03-14 11:30:00      2  0.0384  8.000        NaN   NaN
# 2007-03-28 11:30:00      5  0.0397  6.000        NaN   NaN
# 2007-04-18 11:30:00      2  0.0409  7.000        NaN   NaN
# 2007-05-02 11:30:00      5  0.0416  5.000        NaN   NaN
# 2007-05-23 11:30:00     10  0.0436  7.000        NaN   NaN
# 2007-06-13 11:30:00      2  0.0450  7.000        NaN   NaN
# 2007-06-20 11:30:00      5  0.0450  4.604        NaN   NaN
# 2007-07-04 11:30:00     10  0.0459  6.000        NaN   NaN
# 2007-07-11 11:30:00      2  0.0443  6.220        NaN   NaN
# 2007-07-25 11:30:00     30  0.0452  4.000        NaN   NaN
# 2007-08-15 11:30:00     10  0.0432  6.000        NaN   NaN
# 2007-09-12 11:30:00      2  0.0387  7.000        NaN   NaN
# 2007-09-26 11:30:00      5  0.0417  6.000        NaN   NaN
# 2007-10-10 11:30:00      2  0.0404  6.000        NaN   NaN
# 2007-10-31 11:15:00      5  0.0405  5.000        NaN   NaN
# 2007-11-14 11:04:00     10  0.0419  7.000        NaN   NaN
# 2007-11-28 11:07:00      5  0.0382  5.000        NaN   NaN
# 2007-12-12 11:03:00      2  0.0388  7.000        NaN   NaN
# 2008-01-02 11:15:00     10  0.0435  7.000        NaN   NaN
# 2008-01-16 11:15:00      2  0.0361  7.000        NaN   NaN
# 2008-01-23 11:15:00     30  0.0445  4.000        NaN   NaN
# 2008-02-13 11:15:00     10  0.0394  6.000        NaN   NaN
# 2008-03-05 11:15:00      5     NaN  3.000        NaN   NaN
# 2008-03-12 11:15:00      2  0.0322  8.000        NaN   NaN
# 2008-03-26 11:15:00      5  0.0363  7.000        NaN   NaN
# 2008-04-16 11:15:00      2  0.0352  7.000        NaN   NaN
# 2008-05-07 11:15:00      5  0.0394  5.000        NaN   NaN
# 2008-05-28 11:15:00     10  0.0436  8.000        NaN   NaN
#                        ...     ...    ...        ...   ...
#
# [270 rows x 7 columns]
