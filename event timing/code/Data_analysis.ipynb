# %%
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
inputcsvdir = os.path.abspath('../data/FR')

# %%
df_rx_1 = pd.read_csv(inputcsvdir + '\\BN_2014.csv', index_col= 0, parse_dates= True, infer_datetime_format= True)

# %%
df_rx_2 = pd.read_csv(inputcsvdir + '\\BN_2014_2.csv', index_col= 0, parse_dates= True, infer_datetime_format= True)

# %%
rcParams['figure.figsize'] = 16, 5
df_rx_1['Close'].plot()

# %%
df_rx_2['Close'].plot()
