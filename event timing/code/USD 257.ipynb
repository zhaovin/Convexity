# %%
#setup
import pandas as pd
import numpy as np
import os
import sys
import ConfigParser
from pandas import datetime
from datetime import time, date
import datetime

# read the configuration file and set the path to IDPResearch directory
config = ConfigParser.RawConfigParser()
config.read(os.path.abspath('E:\github\SystematicStrategies\idpresearch.cfg'))
sys.path.append(os.path.abspath(config.get('IDPResearch','libpath_windows')))

from idpresearch import *

params = utillib.PathUtil(projectname = 'US auction', 
                          inputcsvdir = os.path.abspath('../data/US'), 
                          outputdir = os.path.abspath('../output/US'),
                          resourcedir = os.path.abspath(config.get('IDPResearch','libpath_windows') + '/resources'))  
inputcsvdir = os.path.abspath('../data/US')

risk = risklib.Risk()
sig = siglib.Sig()
plt = plotlib.Plot(params)
io = iolib.IO(params)
rcParams['figure.figsize'] = 18, 3

# %%
import ET_utils as et
# %load_ext autoreload
# %autoreload

# %%
#load Event dates
US = pd.read_csv(inputcsvdir +'//'+ 'US_updated.csv', index_col= 0, parse_dates= True, infer_datetime_format= True)
US = US['2009-02-10':'2014-02-01']   # only afer 2009, supply has current pattern
US['Date'] = [x.date() for x in US.index]
US['Week Day'] = [x.weekday() for x in US.index]
US['Day of Month'] = [x.day for x in US.index]
US['Month'] = [x.month for x in US.index]

# %%
Events_dates = set(US['Date'].ix[(US['Tenor'] == 7).values & (US['IIB'] == 0).values])
Events_dates = list((Events_dates))
Events_dates = sort(Events_dates)
Week_days = [i_date.weekday() for i_date in Events_dates]
Event_date_index = pd.DatetimeIndex(Events_dates)
df_week_days = pd.DataFrame(Week_days, index = Event_date_index, columns= ['Week of the day'])
len_events = len(Events_dates)

# %%
#US['Day of Month'].ix[(US['Tenor'] == 7).values & (US['IIB'] == 0).values].value_counts()

# %% [markdown]
# ## Thursday to Monday

# %%
#load main event data
contracts = ['FV', 'TY', 'US', 'ES']
t_index = pd.date_range('2013-01-01 00:01', '2013-01-01 14:56', freq = '5min')
time_zone = 'US/Central'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = -5
day_end = -2
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]

event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates, len_events)

# %%
# plot mean function
def plot_data_mean(data_dict, contracts, index_dates, column_times, plot_date_st, plot_date_ed, day_st, day_end, time_int_n):
    rcParams['figure.figsize'] = 18, 3
    ax1 = grid()
    hold(True)
    for i_contract in contracts:
        #convert to dataframe
        df_data = pd.DataFrame(data = data_dict[i_contract], index = index_dates, columns = column_times)
        df_data.ix[plot_date_st:plot_date_ed].mean(axis = 0).T.plot(ax = ax1, label = i_contract)
    for i in range(1,day_end - day_st):
        axvline(x = i* time_int_n-1, color = 'k')
    legend(loc = 'best') 
    return ax1

# %%
def plot_pos_data(data_pos, index_dates, column_times, plot_date_st, plot_date_ed, day_st, day_end, time_int_n):
    rcParams['figure.figsize'] = 18, 3
    #convert to dataframe
    df_data = pd.DataFrame(data = data_pos, index = index_dates, columns = column_times)
    ax1 = df_data.ix[plot_date_st:plot_date_ed].T.plot(grid = True)
    for i in range(1,day_end - day_st):
        axvline(x= i* time_int_n, color = 'k')
    legend(loc = 'best')
    return ax1

# %%
def Event_pl_pos_output(Assets, data, col_name, filename):
    # save data to filename csv file
    df_data = pd.DataFrame()
    col_list= [x + y for x in Assets for y in col_name]
    for i in range(len(Assets)):
        df_data = pd.concat([df_data, data[i]], axis = 1)
    df_data.columns = col_list
    df_data.to_csv(filename)

# %%
ax1 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, time_interval_str, '2009', '2014', day_st, day_end, time_int_n)

# %%
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 36.0
mean = np.concatenate((np.diff(event_data_vol_adj_dict['TY'],n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['TY'].values.T,(len_events,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_curve_dict['TY' + 'Friday concession'] = 1.0 * pos_1 + 0.0 * pos_2   # pos_1 expanding window, pos_2 rolling window

# %%
#ax1 = plot_pos_data(pos_1, Event_date_index, time_interval_str, '2013', '2014', day_st, day_end, time_int_n)  
#ax2 = plot_pos_data(pos_1, Event_date_index, range(len(time_interval_str)), '2013', '2014', day_st, day_end, time_int_n)
#ax2 = plot_pos_data(pos_2, Event_date_index, time_interval_str, '2013', '2014', day_st, day_end, time_int_n)

# %%
FS = 1000000
gearing = 4.98961535714131   # mean(PL) = 30K
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
Asset = 'TY'
FPV = FPV_dict['TY']
cost_const = cost_const_dict['TY']
df_data = pd.DataFrame(event_data_dict['TY'])
event_vol = event_vol_dict['TY']
pos_curve = pos_curve_dict['TY'+ 'Friday concession'].copy()
pos_curve[:, :90] = 0.0
pos_curve[:, 400:] = 0.0
(pos_curve[:, 90:400])[pos_curve[:, 90:400]> 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

Hedge_Asset = 'ES' 
FPV_hedge = FPV_dict['ES']
cost_const_hedge = cost_const_dict['ES']
df_data_hedge = pd.DataFrame(event_data_dict['ES'])
event_vol_hedge = event_vol_dict['ES']
pos_curve_hedge = pos_curve.copy()

df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = et.get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi + daily_pl_hedge
daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all.ix['2009':], annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl_net'].values)
event_hit_ratio = et.get_hit_ratio((df_pl_fi_events_net.sum(axis = 1) + df_pl_hedge_events_net.sum(axis = 1)).ix['2009':].values)
IR, hit_ratio, hit_ratio_net, event_hit_ratio
gearing/30000.0*(df_pl_fi_events_net.sum(axis = 1) + df_pl_hedge_events_net.sum(axis = 1)).mean()
# Out:
# 4.9896153571413118

# %%
# write to csv
assets = ['TY', 'ES']
event_name = 'USD257_'
signal_name = 'friday_consession'
pl_col_name = [' pl', ' pl_net']
pl_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pl.csv'
pl_data = [df_pl_fi_intraday, df_pl_hedge_intraday]
pos_col_name = [' pos']
pos_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pos.csv'
pos_data = [df_pos_intraday_fi, df_pos_intraday_hedge]
Event_pl_pos_output(assets, pl_data, pl_col_name, pl_filename)
Event_pl_pos_output(assets, pos_data, pos_col_name, pos_filename)

# %% [markdown]
# ## Monday Short Squeeze

# %%
#load main event data
contracts = ['FV', 'TY', 'US', 'ES']
t_index = pd.date_range('2013-01-01 00:01', '2013-01-01 14:56', freq = '5min')
time_zone = 'US/Central'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = -3
day_end = -1
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]
event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates, len_events)

# %%
ax2 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, time_interval_str, '2009', '2014', day_st, day_end, time_int_n)

# %%
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 12.0
# spread as a better signal to trade outright
mean = np.concatenate((np.diff((event_data_vol_adj_dict['FV'] - event_data_vol_adj_dict['US']) ,n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['FV'].values.T,(len_events,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_curve_dict['FV' + 'Monday short squeeze'] = 1.0 * pos_1 + 0.0 * pos_2

# %%
#ax1 = plot_pos_data(pos_1, Event_date_index, time_interval_str, '2013', '2014', day_st, day_end, time_int_n)  
#ax2 = plot_pos_data(pos_1, Event_date_index, range(len(time_interval_str)), '2013', '2014', day_st, day_end, time_int_n)
#ax2 = plot_pos_data(pos_2, Event_date_index, time_interval_str, '2013', '2014', day_st, day_end, time_int_n)

# %%
FS = 1000000
gearing = 0.75   #mean(PL) = 30K
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['FV']
cost_const = cost_const_dict['FV']
df_data = pd.DataFrame(event_data_dict['FV'])
event_vol = event_vol_dict['FV']
pos_curve = pos_curve_dict['FV'+ 'Monday short squeeze'].copy()
pos_curve[:, 0:70] = 0.0
pos_curve[:, 180:] = 0.0
(pos_curve[:, 70:180])[pos_curve[:, 70:180]< 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

#FPV_hedge = FPV_dict['ES']
#cost_const_hedge = cost_const_dict['ES']
#df_data_hedge = pd.DataFrame(event_data_dict['ES'])
#event_vol_hedge = event_vol_dict['ES']
#pos_curve_hedge = pos_curve.copy()

#df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
#daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi
#daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all.ix['2009':], annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl_net'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).ix['2009':].values)
IR, hit_ratio, hit_ratio_net, event_hit_ratio
#gearing/30000* (df_pl_fi_events_net.sum(axis = 1)).mean()
# Out:
# 0.75812565556611922

# %%
# write to csv
assets = ['FV']
event_name = 'USD257_'
signal_name = 'monday_short_squeeze'
pl_col_name = [' pl', ' pl_net']
pl_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pl.csv'
pl_data = [df_pl_fi_intraday]
pos_col_name = [' pos']
pos_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pos.csv'
pos_data = [df_pos_intraday_fi]
Event_pl_pos_output(assets, pl_data, pl_col_name, pl_filename)
Event_pl_pos_output(assets, pos_data, pos_col_name, pos_filename)

# %% [markdown]
# ## Tuesday short squeeze and 5Y auction

# %%
#load main event data
contracts = ['FV', 'TY', 'US', 'ES']
t_index = pd.date_range('2013-01-01 00:01', '2013-01-01 14:56', freq = '5min')
time_zone = 'US/Central'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = -2
day_end = 1
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]
event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates, len_events)

# %%
ax3 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, time_interval_str, '2009', '2014', day_st, day_end, time_int_n)

# %% [markdown]
# #### Tuesday short squeeze

# %%
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 12.0
mean = np.concatenate((np.diff(event_data_vol_adj_dict['TY'],n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['TY'].values.T,(len_events,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_curve_dict['TY' + '2y short squeeze'] = 1.0 * pos_1 + 0.0 * pos_2

# %%
#ax4 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, time_interval_str, '2009', '2014', day_st, day_end, time_int_n)
ax4 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, range(len(time_interval_str)), '2009', '2014', day_st, day_end, time_int_n)

# %%
FS = 1000000
gearing = 1.95  #mean(PL) = 50K
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['TY']
cost_const = cost_const_dict['TY']
df_data = pd.DataFrame(event_data_dict['TY'])
event_vol = event_vol_dict['TY']
pos_curve = pos_curve_dict['TY'+ '2y short squeeze'].copy()
pos_curve[:, 0:70] = 0.0
pos_curve[:, 200:] = 0.0
(pos_curve[:, 70:200])[pos_curve[:, 70:200]< 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

#FPV_hedge = FPV_dict['ES']
#cost_const_hedge = cost_const_dict['ES']
#df_data_hedge = pd.DataFrame(event_data_dict['ES'])
#event_vol_hedge = event_vol_dict['ES']
#pos_curve_hedge = pos_curve.copy()

#df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
#daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi
#daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all.ix['2009':], annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).values)
IR, hit_ratio_net, event_hit_ratio
# Out:
# 49952.851409903618

# %%
# write to csv
assets = ['TY']
event_name = 'USD257_'
signal_name = '2y_short_squeeze'
pl_col_name = [' pl', ' pl_net']
pl_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pl.csv'
pl_data = [df_pl_fi_intraday]
pos_col_name = [' pos']
pos_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pos.csv'
pos_data = [df_pos_intraday_fi]
Event_pl_pos_output(assets, pl_data, pl_col_name, pl_filename)
Event_pl_pos_output(assets, pos_data, pos_col_name, pos_filename)

# %% [markdown]
# #### 5 year concession

# %%
# positioning, ES as an asset to get long position
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 12.0
mean = np.concatenate((np.diff(event_data_vol_adj_dict['FV'],n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['FV'].values.T,(len_events,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_curve_dict['FV' + 'concession'] = 1.0 * pos_1 + 0.0 * pos_2

# %%
ax1 = plot_pos_data(pos_1, Event_date_index, range(len(time_interval_str)), '2013', '2013', day_st, day_end, time_int_n)
legend(loc = 'center left')
#ax2 = plot_pos_data(pos_1, Event_date_index, range(len(time_interval_str)), '2013', '2014', day_st, day_end, time_int_n)
ax2 = plot_pos_data(pos_2, Event_date_index, time_interval_str, '2013', '2013', day_st, day_end, time_int_n)
legend(loc = 'center left')

# %%
FS = 1000000
gearing = 20
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['TY']     # TY as a proxy due to trading cost
cost_const = cost_const_dict['TY']
df_data = pd.DataFrame(event_data_dict['TY'])
event_vol = event_vol_dict['TY']
pos_curve = pos_curve_dict['FV'+ 'concession'].copy()
pos_curve[:, 0:240] = 0.0
pos_curve[:, 270:] = 0.0
(pos_curve[:, 240:270])[pos_curve[:, 240:270]> 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

FPV_hedge = FPV_dict['ES']
cost_const_hedge = cost_const_dict['ES']
df_data_hedge = pd.DataFrame(event_data_dict['ES'])
event_vol_hedge = event_vol_dict['ES']
pos_curve_hedge = pos_curve.copy()

df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = et.get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi + daily_pl_hedge
daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all.ix['2009':], annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).values + df_pl_hedge_events_net.sum( axis = 1).values)
IR, hit_ratio_net, event_hit_ratio
# Out:
# (pl        0.975747
# pl_net    0.081760
# dtype: float64,
#  0.6440677966101694,
#  0.5254237288135594)

# %% [markdown]
# #### 5 year buy all through auction

# %%
# positioning, ES as an asset to get long position
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 12.0
mean = np.concatenate((np.diff(event_data_vol_adj_dict['ES'],n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['ES'].values.T,(len_events,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_curve_dict['FV' + '5 year buy all through auction'] = 0.55 * pos_1 + 0.45 * pos_2

# %%
FS = 1000000
gearing = 1.89  # mean(PL) = 50K
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['FV']
cost_const = cost_const_dict['FV']
df_data = pd.DataFrame(event_data_dict['FV'])
event_vol = event_vol_dict['FV']
pos_curve = pos_curve_dict['FV'+ '5 year buy all through auction'].copy()
pos_curve[:, 0:280] = 0.0
pos_curve[:, 400:] = 0.0
(pos_curve[:, 280:400])[pos_curve[:, 280:400]< 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

FPV_hedge = FPV_dict['ES']
cost_const_hedge = cost_const_dict['ES']
df_data_hedge = pd.DataFrame(event_data_dict['ES'])
event_vol_hedge = event_vol_dict['ES']
pos_curve_hedge = pos_curve.copy()

df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = et.get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi + daily_pl_hedge
daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all.ix['2009':], annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all.ix['2009':]['pl'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).values + df_pl_hedge_events_net.sum( axis = 1).values)
IR, hit_ratio_net, event_hit_ratio
# Out:
# (pl        1.426854
# pl_net    0.943505
# dtype: float64,
#  0.5847457627118644,
#  0.6610169491525424)

# %%
# write to csv
assets = ['FV', 'ES']
event_name = 'USD257_'
signal_name = '5y_buyall'
pl_col_name = [' pl', ' pl_net']
pl_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pl.csv'
pl_data = [df_pl_fi_intraday, df_pl_hedge_intraday]
pos_col_name = [' pos']
pos_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pos.csv'
pos_data = [df_pos_intraday_fi, df_pos_intraday_hedge]
Event_pl_pos_output(assets, pl_data, pl_col_name, pl_filename)
Event_pl_pos_output(assets, pos_data, pos_col_name, pos_filename)

# %% [markdown]
# ## TY Concession on 7-year auction

# %%
#load main event data
contracts = ['FV', 'TY', 'US', 'ES']
t_index = pd.date_range('2013-01-01 00:01', '2013-01-01 14:56', freq = '5min')
time_zone = 'US/Central'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = 0
day_end = 2 
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]
event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates, len_events)

# %%
#ax4 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, time_interval_str, '2009', '2014', day_st, day_end, time_int_n)
ax4 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, range(len(time_interval_str)), '2009', '2014', day_st, day_end, time_int_n)

# %%
# positioning
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 6.0
mean = np.concatenate((np.diff(event_data_vol_adj_dict['TY'],n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['TY'].values.T,(len_events,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_curve_dict['TY' + 'concession'] = 0.5 * pos_1 + 0.5 * pos_2

# %%
FS = 1000000
gearing = 0.66    # mean(PL) = 30K
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['TY']
cost_const = cost_const_dict['TY']
df_data = pd.DataFrame(event_data_dict['TY'])
event_vol = event_vol_dict['TY']
pos_curve = pos_curve_dict['TY'+ 'concession'].copy()
pos_curve[:, 0:40] = 0.0
pos_curve[:, 90:] = 0.0
(pos_curve[:, 40:90])[pos_curve[:, 40: 90]> 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

#FPV_hedge = FPV_dict['ES']
#cost_const_hedge = cost_const_dict['ES']
#df_data_hedge = pd.DataFrame(event_data_dict['ES'])
#event_vol_hedge = event_vol_dict['ES']
#pos_curve_hedge = pos_curve.copy()

#df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
#daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi
#daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all.ix['2012':], annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all.ix['2012':]['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all.ix['2012':]['pl'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).ix['2012':].values)
IR, hit_ratio_net, event_hit_ratio
# Out:
# 0.67512146787395633

# %%
assets = ['TY']
event_name = 'USD257_'
signal_name = '7y_consession'
pl_col_name = [' pl', ' pl_net']
pl_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pl.csv'
pl_data = [df_pl_fi_intraday.ix['2012':]]
pos_col_name = [' pos']
pos_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pos.csv'
pos_data = [df_pos_intraday_fi.ix['2012':]]
Event_pl_pos_output(assets, pl_data, pl_col_name, pl_filename)
Event_pl_pos_output(assets, pos_data, pos_col_name, pos_filename)

# %% [markdown]
# ## Rally into 7 year Auction: the trade is due to short covering before the auction, but it seems equity part doing particular good.

# %%
#load main event data
contracts = ['FV', 'TY', 'US', 'ES']
t_index = pd.date_range('2013-01-01 00:01', '2013-01-01 14:56', freq = '5min')
time_zone = 'US/Central'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = 0
day_end = 2 
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]
event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates, len_events)

# %%
ax5 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, time_interval_str, '2009', '2014', day_st, day_end, time_int_n)
#ax6 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, range(len(time_interval_str)), '2009', '2014', day_st, day_end, time_int_n)

# %%
# positioning
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 6.0
mean = np.concatenate((np.diff(event_data_vol_adj_dict['TY'],n=1,axis = 1), np.zeros((len_events, 1))), 1)
variance = np.tile(df_variance_profile['TY'].values.T,(len_events,day_end - day_st))
#pos_1, pos_2 = generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 120, 160)
pos_curve_dict['TY' + '7y rally into auction'] = 1.0 * pos_1 + 0.0 * pos_2

# %%
FS = 1000000
gearing = 1.308  # mean(PL) = 40K
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['TY']
cost_const = cost_const_dict['TY']
df_data = pd.DataFrame(event_data_dict['TY'])
event_vol = event_vol_dict['TY']
pos_curve = pos_curve_dict['TY'+ '7y rally into auction'].copy()
pos_curve[:, 0:130] = 0.0
pos_curve[:, 150:] = 0.0
(pos_curve[:, 130:150])[pos_curve[:, 130:150]< 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates, event_data_date_time)
daily_pl_fi.cumsum().plot()

FPV_hedge = FPV_dict['ES']
cost_const_hedge = cost_const_dict['ES']
df_data_hedge = pd.DataFrame(event_data_dict['ES'])
event_vol_hedge = event_vol_dict['ES']
pos_curve_hedge = pos_curve.copy()

df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = et.get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates, event_data_date_time)
daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi + daily_pl_hedge
daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all, annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all['pl'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).values + df_pl_hedge_events_net.sum( axis = 1).values)
IR, hit_ratio_net, event_hit_ratio
# Out:
# 40026.262655537801

# %%
# write to csv
assets = ['TY', 'ES']
event_name = 'USD257_'
signal_name = '7y_buyall'
pl_col_name = [' pl', ' pl_net']
pl_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pl.csv'
pl_data = [df_pl_fi_intraday, df_pl_hedge_intraday]
pos_col_name = [' pos']
pos_filename = inputcsvdir + '\\'+ event_name + signal_name + '_intraday_pos.csv'
pos_data = [df_pos_intraday_fi, df_pos_intraday_hedge]
Event_pl_pos_output(assets, pl_data, pl_col_name, pl_filename)
Event_pl_pos_output(assets, pos_data, pos_col_name, pos_filename)

# %% [markdown]
# ## Rally after 7 year Auction: No good trade found.. maybe just run Month end trade

# %%
#load main event data
contracts = ['FV', 'TY', 'US', 'ES']
t_index = pd.date_range('2013-01-01 00:01', '2013-01-01 14:56', freq = '5min')
time_zone = 'US/Central'
time_interval = [t.time() for t in t_index]
time_int_n = len(time_interval)
day_st  = 0
day_end = 3 
time_interval_str = [itime.strftime("%H:%M") for itime in time_interval*(day_end -day_st)]
event_vol_dict, df_variance_profile, event_data_dict, event_data_vol_adj_dict, event_data_date_time  = et.get_event_intraday_data_outright(inputcsvdir, contracts, time_interval, time_int_n, time_zone, day_st, day_end, Events_dates[:-1], len_events-1)

# %%
ax7 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index[:-1], time_interval_str, '2009', '2014', day_st, day_end, time_int_n)
#ax6 = plot_data_mean(event_data_vol_adj_dict, ['US','TY','FV', 'ES'], Event_date_index, range(len(time_interval_str)), '2009', '2014', day_st, day_end, time_int_n)

# %%
# positioning
pos_curve_dict = {}
ewma_seedperiod = 12
window_size = 12
smooth_window = 12.0
mean = np.concatenate((np.diff((1*event_data_vol_adj_dict['TY'] + 1*event_data_vol_adj_dict['ES']) ,n=1,axis = 1), np.zeros((len_events-1, 1))), 1)
variance = np.tile(df_variance_profile['TY'].values.T,(len_events -1,day_end - day_st))
pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 0*time_int_n, (day_end - day_st)*time_int_n)
#pos_1, pos_2 = et.generate_pos_curve(mean, variance, ewma_seedperiod, window_size, smooth_window, 120, 160)
pos_curve_dict['TY' + 'after 7y auction'] = 1.0 * pos_1 + 0.0 * pos_2

# %%
ax1 = plot_pos_data(pos_1, Event_date_index[:-1], range(len(time_interval_str)), '2013', '2013', day_st, day_end, time_int_n)
legend(loc = 'center left')
#ax2 = plot_pos_data(pos_1, Event_date_index, range(len(time_interval_str)), '2013', '2014', day_st, day_end, time_int_n)
ax2 = plot_pos_data(pos_2, Event_date_index[:-1], time_interval_str, '2013', '2013', day_st, day_end, time_int_n)
legend(loc = 'center left')

# %%
FS = 1000000
gearing = 20
FPV_dict = {'FV': 1000, 'TY': 1000, 'US': 1000, 'WN': 1000, 'ES': 50}
cost_const_dict = {'FV': 0.5*1.0/64, 'TY': 0.5*1.0/64, 'US': 0.5*1.0/32, 'WN': 0.5*1.0/32, 'ES': 0.5*0.25}
FPV = FPV_dict['TY']
cost_const = cost_const_dict['TY']
df_data = pd.DataFrame(event_data_dict['TY'])
event_vol = event_vol_dict['TY']
pos_curve = pos_curve_dict['TY'+ 'after 7y auction'].copy()
#pos_curve[:, 0:170] = 0.0
#pos_curve[:, 260:440] = 0.0
#(pos_curve[:, 170:260])[pos_curve[:, 170:260]< 0.0] = 0.0
#pos_curve[:, 0:440] = 0.0
#pos_curve[:, 490:] = 0.0
pos_curve[:, 0:320] = 0.0
pos_curve[:, 380:] = 0.0
#(pos_curve[:, 440:490])[pos_curve[:, 440:490]< 0.0] = 0.0

df_pl_fi_intraday, daily_pl_fi, df_pos_intraday_fi, daily_pos_fi, df_pl_fi_events, df_pl_fi_events_net = et.get_pl_pos(FS, gearing, cost_const, FPV, df_data, pos_curve, event_vol, Events_dates[:-1], event_data_date_time)
daily_pl_fi.cumsum().plot()

FPV_hedge = FPV_dict['ES']
cost_const_hedge = cost_const_dict['ES']
df_data_hedge = pd.DataFrame(event_data_dict['ES'])
event_vol_hedge = event_vol_dict['ES']


df_pl_hedge_intraday, daily_pl_hedge, df_pos_intraday_hedge, daily_pos_hedge, df_pl_hedge_events, df_pl_hedge_events_net  = et.get_pl_pos(FS, gearing, cost_const_hedge, FPV_hedge, df_data_hedge, pos_curve_hedge, event_vol_hedge, Events_dates[:-1], event_data_date_time)
daily_pl_hedge.cumsum().plot()

daily_pl_all = daily_pl_fi + daily_pl_hedge
daily_pl_all.cumsum().plot()

#PL analysis
btest = btestlib.Backtest(params)
IR = btest.calc_IR(daily_pl_all, annual_factor= 252)
hit_ratio = et.get_hit_ratio(daily_pl_all['pl'].values)
hit_ratio_net = et.get_hit_ratio(daily_pl_all['pl'].values)
event_hit_ratio = et.get_hit_ratio(df_pl_fi_events_net.sum(axis = 1).values + df_pl_hedge_events_net.sum( axis = 1).values)
IR, hit_ratio_net, event_hit_ratio
# Out:
# (pl        0.457140
# pl_net    0.060672
# dtype: float64, 0.5269461077844312, 0.5)
